# %%
# %load_ext autoreload

from pathlib import Path
import csv
from pprint import pprint
import collections
import itertools

from tqdm import tqdm, trange

import numpy as np

from scipy import ndimage as ndi

import networkx as nx
from dataclasses import dataclass

import skimage
import skimage.feature
import skimage.filters
import skimage.morphology
import skimage.segmentation as seg
import skimage.measure

import cv2 as cv

from bokeh.plotting import output_notebook, figure, show
from bokeh.layouts import column, row, layout, gridplot
from bokeh.models import ColumnDataSource, Slider

import matplotlib.pyplot as plt

# %matplotlib inline

import fish

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
THIS_DIR = Path.cwd()
ROOT_DIR = THIS_DIR.parent
DATA_DIR = ROOT_DIR / 'data'

# %%
@dataclass(frozen = True)
class Point:
    index: int
    frame: int
    x: float
    y: float
    area: float
    perimeter: float
        
    def distance_to(self, p):
        return np.sqrt(((self.x - p.x) ** 2) + ((self.y - p.y) ** 2))

# %%
points = []
with (THIS_DIR / "D1-1__lower=25_upper=200_smoothing=3__centroids.csv").open(newline='') as f:
    spamreader = csv.reader(f, delimiter=',')
    for idx, (frame, x, y, area, perimeter) in enumerate(spamreader):
        points.append(Point(idx, int(frame), float(x), float(y), float(area), float(perimeter)))

# %%
print(len(points))
pprint(points[:10])
# Out:
# 61069
# [Point(index=0, frame=0, x=886.9304782298358, y=789.5497501784439, area=1167.5, perimeter=179.5807341337204),
#  Point(index=1, frame=0, x=805.4095607235141, y=774.6976744186046, area=258.0, perimeter=84.42640614509583),
#  Point(index=2, frame=0, x=404.2520391517129, y=725.5921696574225, area=613.0, perimeter=110.91168737411499),
#  Point(index=3, frame=0, x=1004.6421052631579, y=711.0315789473684, area=47.5, perimeter=29.55634891986847),
#  Point(index=4, frame=0, x=763.6103513006168, y=721.1182622687047, area=621.5, perimeter=107.15432798862457),
#  Point(index=5, frame=0, x=810.66968053044, y=680.2194092827004, area=276.5, perimeter=71.01219260692596),
#  Point(index=6, frame=0, x=833.7481481481481, y=655.5041394335511, area=382.5, perimeter=83.84061968326569),
#  Point(index=7, frame=0, x=651.4521426738517, y=635.757505773672, area=649.5, perimeter=110.81118214130402),
#  Point(index=8, frame=0, x=946.8632707774799, y=630.305183199285, area=373.0, perimeter=114.56854152679443),
#  Point(index=9, frame=0, x=339.7536945812808, y=623.0484400656815, area=203.0, perimeter=61.11269783973694)]

# %%
def group_by_frame(points):
    groups = collections.defaultdict(list)
    
    for point in points:
        groups[point.frame].append(point)
        
    return dict(groups.items())

# %%
by_frame = group_by_frame(points)
last_frame = len(by_frame) - 1

# %%
def window(seq, n):
    "Returns a sliding window (of width n) over data from the iterable"
    "   s -> (s0,s1,...s[n-1]), (s1,s2,...,sn), ...                   "
    it = iter(seq)
    result = tuple(itertools.islice(it, n))
    if len(result) == n:
        yield result
    for elem in it:
        result = result[1:] + (elem,)
        yield result
        
for a, b in window(range(5), 2):
    print(a, b)
# Out:
# 0 1
# 1 2
# 2 3
# 3 4

# %%
g = nx.DiGraph()

for (curr_index, curr_points), (next_index, next_points) in window(tqdm(list(sorted(by_frame.items(), key = lambda x: x[0]))), 2):
    edges = [(a, b, a.distance_to(b)) for a, b in itertools.product(curr_points, next_points)]
    g.add_weighted_edges_from(edges)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1716/1716 [00:17<00:00, 100.75it/s]

# %%
print(g)
print(len(g.nodes))
print(len(g.edges))
# Out:
# 61069
# 2183132

# %%
starts = by_frame[0]
ends = by_frame[last_frame]

# %%
pprint(starts)
pprint(ends)
# Out:
# [Point(index=0, frame=0, x=886.9304782298358, y=789.5497501784439, area=1167.5, perimeter=179.5807341337204),
#  Point(index=1, frame=0, x=805.4095607235141, y=774.6976744186046, area=258.0, perimeter=84.42640614509583),
#  Point(index=2, frame=0, x=404.2520391517129, y=725.5921696574225, area=613.0, perimeter=110.91168737411499),
#  Point(index=3, frame=0, x=1004.6421052631579, y=711.0315789473684, area=47.5, perimeter=29.55634891986847),
#  Point(index=4, frame=0, x=763.6103513006168, y=721.1182622687047, area=621.5, perimeter=107.15432798862457),
#  Point(index=5, frame=0, x=810.66968053044, y=680.2194092827004, area=276.5, perimeter=71.01219260692596),
#  Point(index=6, frame=0, x=833.7481481481481, y=655.5041394335511, area=382.5, perimeter=83.84061968326569),
#  Point(index=7, frame=0, x=651.4521426738517, y=635.757505773672, area=649.5, perimeter=110.81118214130402),
#  Point(index=8, frame=0, x=946.8632707774799, y=630.305183199285, area=373.0, perimeter=114.56854152679443),
#  Point(index=9, frame=0, x=339.7536945812808, y=623.0484400656815, area=203.0, perimeter=61.11269783973694),
#  Point(index=10, frame=0, x=994.8869047619047, y=605.8753720238094, area=448.0, perimeter=100.71067690849304),
#  Point(index=11, frame=0, x=897.7717739945718, y=606.1556871453244, area=675.5, perimeter=117.63960921764374),
#  Point(index=12, frame=0, x=390.1032018296169, y=595.122641509434, area=583.0, perimeter=101.74011445045471),
#  Point(index=13, frame=0, x=841.8848691695108, y=584.2191126279863, area=732.5, perimeter=121.29646337032318),
#  Point(index=14, frame=0, x=764.07111834962, y=561.4169381107491, area=307.0, perimeter=77.5979790687561),
#  Point(index=15, frame=0, x=886.1652397260274, y=565.9728881278538, area=584.0, perimeter=116.56854152679443),
#  Point(index=16, frame=0, x=572.5038115038114, y=531.7522522522522, area=481.0, perimeter=101.39696860313416),
#  Point(index=17, frame=0, x=754.023289665211, y=528.6069868995634, area=458.0, perimeter=85.94112491607666),
#  Point(index=18, frame=0, x=853.1386701662292, y=516.7300962379702, area=381.0, perimeter=107.39696860313416),
#  Point(index=19, frame=0, x=311.3513920240782, y=504.3916478555305, area=443.0, perimeter=95.74011445045471),
#  Point(index=61067, frame=1715, x=689.5913978494623, y=142.96236559139783, area=31.0, perimeter=22.485281229019165),
#  Point(index=61068, frame=1715, x=632.8782343987823, y=56.153729071537285, area=219.0, perimeter=77.94112491607666)]

# %%
shortest_paths = {}
for start in tqdm(starts):
    paths = nx.shortest_path(g, source = start, weight = 'weight')
    for end, path in paths.items():
        shortest_paths[start, end] = path
# Out:
#   0%|                                                                                                                                                                              | 0/41 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#   2%|████                                                                                                                                                                  | 1/41 [00:09<06:02,  9.05s/it]
#
#
#
#
#
#
#
#
#   5%|████████                                                                                                                                                              | 2/41 [00:19<06:04,  9.35s/it]
#
#
#
#
#
#
#
#
#   7%|████████████▏                                                                                                                                                         | 3/41 [00:28<05:56,  9.38s/it]
#
#
#
#
#
#
#
#
#  10%|████████████████▏                                                                                                                                                     | 4/41 [00:38<05:51,  9.51s/it]
#
#
#
#
#
#
#
#
#  12%|████████████████████▏                                                                                                                                                 | 5/41 [00:51<06:20, 10.58s/it]
#
#
#
#
#
#
#
#
#  15%|████████████████████████▎                                                                                                                                             | 6/41 [01:05<06:46, 11.62s/it]
#
#
#
#
#
#
#
#
#  17%|████████████████████████████▎                                                                                                                                         | 7/41 [01:19<07:04, 12.48s/it]
#
#
#
#
#
#
#
#
#  20%|████████████████████████████████▍                                                                                                                                     | 8/41 [01:32<06:55, 12.58s/it]
#
#
#
#
#
#
#
#
#  22%|████████████████████████████████████▍                                                                                                                                 | 9/41 [01:47<07:03, 13.24s/it]
#
#
#
#
#
#
#
#
#  24%|████████████████████████████████████████▏                                                                                                                            | 10/41 [01:55<06:05, 11.78s/it]
#
#
#
#
#
#
#
#
#  27%|████████████████████████████████████████████▎                                                                                                                        | 11/41 [02:09<06:05, 12.19s/it]
#
#
#
#
#
#
#
#
#  29%|████████████████████████████████████████████████▎                                                                                                                    | 12/41 [02:18<05:28, 11.32s/it]
#
#
#
#
#
#
#
#
#  32%|████████████████████████████████████████████████████▎                                                                                                                | 13/41 [02:31<05:31, 11.86s/it]
#
#
#
#
#
#
#
#
#  34%|████████████████████████████████████████████████████████▎                                                                                                            | 14/41 [02:46<05:42, 12.69s/it]
#
#
#
#
#
#
#
#
#  37%|████████████████████████████████████████████████████████████▎                                                                                                        | 15/41 [02:55<05:03, 11.68s/it]
#
#
#
#
#
#
#
#
#  39%|████████████████████████████████████████████████████████████████▍                                                                                                    | 16/41 [03:11<05:27, 13.09s/it]
#
#
#
#
#
#
#
#
#  41%|████████████████████████████████████████████████████████████████████▍                                                                                                | 17/41 [03:24<05:10, 12.92s/it]
#
#
#
#
#
#
#
#
#  44%|████████████████████████████████████████████████████████████████████████▍                                                                                            | 18/41 [03:34<04:38, 12.13s/it]
#
#
#
#
#
#
#
#
#  46%|████████████████████████████████████████████████████████████████████████████▍                                                                                        | 19/41 [04:20<08:12, 22.39s/it]
